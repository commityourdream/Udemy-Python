# %%
import pandas as pd

# %%
stats=pd.read_csv('DemographicData.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
len(stats)
##To Know Number Of Rows
# Out:
# 195

# %%
stats.columns
# Out:
# Index([u'Country Name', u'Country Code', u'Birth rate', u'Internet users',
#        u'Income Group'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 5

# %%
###To Print Top Rows

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(6)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
##BottomRows
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
####Information Of the columns

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
###Gets stats on column

# %%
stats.describe()   #This is summary Function in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# # Renaming Of Columns

# %%
stats.columns=['a','b','c','d','e']

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns=['Country Name','Country Code','Birth Rate','Internet Users','Income Group']

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# # Subsetting Of DataFrames in Pandas

# %%
stats[21:26]
# Out:
#    Country Name Country Code  Birth Rate  Internet Users         Income Group
# 21       Belize          BLZ      23.092           33.60  Upper middle income
# 22      Bermuda          BMU      10.400           95.30          High income
# 23      Bolivia          BOL      24.236           36.94  Lower middle income
# 24       Brazil          BRA      14.931           51.04  Upper middle income
# 25     Barbados          BRB      12.188           73.00          High income

# %%
stats[:]
# Out:
#                        Country Name Country Code  Birth Rate  Internet Users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
stats[185:]
# Out:
#               Country Name Country Code  Birth Rate  Internet Users  \
# 185  Virgin Islands (U.S.)          VIR      10.700            45.3
# 186                Vietnam          VNM      15.537            43.9
# 187                Vanuatu          VUT      26.739            11.3
# 188     West Bank and Gaza          PSE      30.394            46.6
# 189                  Samoa          WSM      26.172            15.3
# 190            Yemen, Rep.          YEM      32.947            20.0
# 191           South Africa          ZAF      20.850            46.5
# 192       Congo, Dem. Rep.          COD      42.394             2.2
# 193                 Zambia          ZMB      40.471            15.4
# 194               Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# ...

# %%
stats[:10]
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
###Reverse The DataFrame

# %%
stats[::-1]
# Out:
#                        Country Name Country Code  Birth Rate  Internet Users  \
# 194                        Zimbabwe          ZWE      35.715        18.50000
# 193                          Zambia          ZMB      40.471        15.40000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 191                    South Africa          ZAF      20.850        46.50000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 189                           Samoa          WSM      26.172        15.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 187                         Vanuatu          VUT      26.739        11.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# ...

# %%
stats[::20]
# Out:
#     Country Name Country Code  Birth Rate  Internet Users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
###Columns###

# %%
stats.columns
# Out:
# Index([u'Country Name', u'Country Code', u'Birth Rate', u'Internet Users',
#        u'Income Group'],
#       dtype='object')

# %%
stats['Country Name']
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %%
stats['Country Name'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: Country Name, dtype: object

# %%
stats[['Country Name','Birth Rate']].head()
# Out:
#            Country Name  Birth Rate
# 0                 Aruba      10.244
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044

# %%
###Quick-Access(Requires the name to be one word)

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['Internet Users']
#stats$Internet Users in R
# Out:
# 0      78.90000
# 1       5.90000
# 2      19.10000
# 3      57.20000
# 4      88.00000
# 5      59.90000
# 6      41.90000
# 7      63.40000
# 8      83.00000
# 9      80.61880
# 10     58.70000
# 11      1.30000
# 12     82.17020
# 13      4.90000
# 14      9.10000
# 15      6.63000
# 16     53.06150
# 17     90.00004
# 18     72.00000
# 19     57.79000
# 20     54.17000
# 21     33.60000
# 22     95.30000
# 23     36.94000
# 24     51.04000
# 25     73.00000
# 26     64.50000
# 27     29.90000
# 28     15.00000
# 29      3.50000
#          ...
# 165    50.40000
# 166    26.20000
# 167     2.30000
# 168     4.50000
# 169    28.94000
# 170    16.00000
# 171     9.60000
# 172     1.10000
# 173    35.00000
# 174    63.80000
# 175    43.80000
# 176    46.25000
# 177     4.40000
# 178    16.20000
# 179    41.00000
# 180    57.69000
# 181    84.20000
# 182    38.20000
# 183    52.00000
# 184    54.90000
# 185    45.30000
# 186    43.90000
# 187    11.30000
# 188    46.60000
# ...

# %%
###Combining the two

# %%
stats[1:8][['Country Name','Birth Rate']]
# Out:
#            Country Name  Birth Rate
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044
# 5             Argentina      17.716
# 6               Armenia      13.308
# 7   Antigua and Barbuda      16.447

# %%
stats[['Country Name','Birth Rate']][1:8]
# Out:
#            Country Name  Birth Rate
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044
# 5             Argentina      17.716
# 6               Armenia      13.308
# 7   Antigua and Barbuda      16.447

# %%
df2=stats[['Country Name','Birth Rate']]
df2[1:8]
# Out:
#            Country Name  Birth Rate
# 1           Afghanistan      35.253
# 2                Angola      45.985
# 3               Albania      12.877
# 4  United Arab Emirates      11.044
# 5             Argentina      17.716
# 6               Armenia      13.308
# 7   Antigua and Barbuda      16.447

# %% [markdown]
# # Basic Operation With DataFrame

# %%
#Mathematical Operations

# %%
result = stats['Birth Rate'] * stats['Internet Users']

# %%
result
# Out:
# 0       808.251600
# 1       207.992700
# 2       878.313500
# 3       736.564400
# 4       971.872000
# 5      1061.188400
# 6       557.605200
# 7      1042.739800
# 8      1095.600000
# 9       757.816720
# 10     1074.210000
# 11       57.396300
# 12      920.306240
# 13      178.556000
# 14      369.014100
# 15      133.541460
# 16      488.165800
# 17     1353.600597
# 18     1104.408000
# 19      523.692980
# 20      677.125000
# 21      775.891200
# 22      991.120000
# 23      895.277840
# 24      762.078240
# 25      889.724000
# 26     1058.122500
# 27      542.206600
# 28      379.005000
# 29      119.266000
#           ...
# 165     937.440000
# 166     629.926600
# 167     105.213500
# 168     162.360000
# 169     319.526540
# 170     492.672000
# 171     204.691200
# 172      39.330500
# 173     889.315000
# 174     930.842000
# 175     867.240000
# 176     778.665000
# 177     173.879200
# 178     704.278800
# 179     455.100000
# 180     829.236060
# ...

# %%
#####Comaprison to R

# %%
stats['xyz'] = [1,2,3,4,5]    #No Recycling Option
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-73bee3a0a621> in <module>()
# ----> 1 stats['xyz'] = [1,2,3,4,5]    #No Recycling Option
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    3114         else:
#    3115             # set column
# -> 3116             self._set_item(key, value)
#    3117
#    3118     def _setitem_slice(self, key, value):
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    3189
#    3190         self._ensure_valid_index(value)
# -> 3191         value = self._sanitize_column(key, value)
#    3192         NDFrame._set_item(self, key, value)
#    3193
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value, broadcast)
#    3386
# ...

# %%
######Removing a columns##########

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.drop('Income Group')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-1ef30ee6f97f> in <module>()
# ----> 1 stats.drop('Income Group')
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
stats.drop('Income Group',1)
# Out:
#                        Country Name Country Code  Birth Rate  Internet Users
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %% [markdown]
# # ##Filtering of DataFrame#########

# %%
stats["Internet users < 2"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-38f0e2c22335> in <module>()
# ----> 1 stats["Internet users < 2"]
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
df_filtered = stats.query('Birth Rate<2')
print(df_filtered)
# Out:
#   File "<unknown>", line 1
#     Birth Rate <2
#              ^
# SyntaxError: invalid syntax

# %%
Filter=stats.Internet Users < 2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-07e49c174b27> in <module>()
# ----> 1 Filter=stats.InternetUsers < 2
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'InternetUsers'

# %%
stats[2:7]
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
#
#           Income Group
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
stats[Filter]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-59e9acf78583> in <module>()
# ----> 1 stats[Filter]
#
# NameError: name 'Filter' is not defined

# %%
stats[stats.Birth Rate > 40]
# Out:
#   File "<ipython-input-80-9f5848ba2490>", line 1
#     stats[stats.Birth Rate > 40]
#                          ^
# SyntaxError: invalid syntax

# %%
Filter2=["stats.Birth Rate > 40"]

# %%
print Filter2
# Out:
# ['stats.Birth Rate > 40']

# %%
stats["Birth Rate>40"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-aee9433f0db7> in <module>()
# ----> 1 stats["Birth Rate>40"]
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
stats[stats.Birth Rate > 40 and stats.Internet Users < 2]
# Out:
#   File "<ipython-input-84-0d7d8f447dcb>", line 1
#     stats[stats.Birth Rate > 40 and stats.Internet Users < 2]
#                          ^
# SyntaxError: invalid syntax

# %%
stats[Filter & Filter2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-fc8e084311ae> in <module>()
# ----> 1 stats[Filter & Filter2]
#
# NameError: name 'Filter' is not defined

# %%
stats[(stats.Birth Rate > 40) & (stats.Internet Users < 2)]
# Out:
#   File "<ipython-input-87-2c2588a928d1>", line 1
#     stats[(stats.Birth Rate > 40) & (stats.Internet Users < 2)]
#                           ^
# SyntaxError: invalid syntax

# %%
stats.head()
# Out:
#            Country Name Country Code  Birth Rate  Internet Users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[stats.Income Group =="High income"]
# Out:
#   File "<ipython-input-91-eb89648eff05>", line 1
#     stats[stats.Income Group =="High income"]
#                            ^
# SyntaxError: invalid syntax

# %%
#########_How To Get Unique Categories_#########

# %%
stats.Income Group.unique()
# Out:
#   File "<ipython-input-93-fd07fa6fd931>", line 1
#     stats.Income Group.unique()
#                      ^
# SyntaxError: invalid syntax

# %%
stats[stats.Country Name == "Aruba"]
# Out:
#   File "<ipython-input-95-c13adf9d0f33>", line 1
#     stats[stats.Country Name == "Aruba"]
#                            ^
# SyntaxError: invalid syntax

# %%
######_Accessing Individual_Element_#########

# %%
stats[2,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-d9036ffc2c84> in <module>()
# ----> 1 stats[2,2]
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# /Users/amitk/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    2484         res = cache.get(item)
# ...

# %% [markdown]
# # .at #for labels #####even integer are treated as label

# %% [markdown]
# # .iat for location of integer

# %%
stats.iat[6,4]
# Out:
# 'Lower middle income'

# %%
stats.iat[0,1]
# Out:
# 'ABW'

# %%
stats.at[2,'Birth Rate']
# Out:
# 45.985

# %%
sub10 = stats[::20]

# %%
sub10
# Out:
#     Country Name Country Code  Birth Rate  Internet Users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
sub10.iat[4,0]
# Out:
# 'India'

# %%
sub10.at[80,'Country Name']
# Out:
# 'India'
